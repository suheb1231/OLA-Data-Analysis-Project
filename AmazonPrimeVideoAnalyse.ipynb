# %% [markdown]
# <a href="https://colab.research.google.com/github/suheb1231/OLA-Data-Analysis-Project/blob/main/AmazonPrimeVideoAnalyse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * import liberaries

# %%
# import liberaries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#dataset load

# %% [markdown]
# ## Load the Dataset

# %%
df = pd.read_csv("/content/drive/MyDrive/almabetter practise data/titles.csv")

# %%
df.head()
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
#                                               genres production_countries  \
# ...

# %%
#columns
df.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
# information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
#  14  tmdb_score            7789 non-null   float64
# ...

# %% [markdown]
# # Categorical col: title,type,description,age_certification,genres , production_countries
#
# # Numerical Col : 	release_year	runtime	seasons	imdb_score	imdb_votes	tmdb_popularity	tmdb_score	person_id
#
# # Mixed Col : id ,imdb_id	id

# %% [markdown]
# # Univarient Analysis Column Wise

# %% [markdown]
# ### title

# %%
# top 5 records
df['title'].head()
# Out:
# 0              The Three Stooges
# 1                    The General
# 2    The Best Years of Our Lives
# 3                His Girl Friday
# 4              In a Lonely Place
# Name: title, dtype: object

# %%
# checking null values
df['title'].isnull().sum()
# Out:
# np.int64(0)

# %%
#checking dplicates
df.duplicated().sum()
# Out:
# np.int64(3)

# %%
# drop duplicates values
df.drop_duplicates(inplace=True)

# %%
missing = df.isnull().sum()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9868 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9868 non-null   object
#  1   title                 9868 non-null   object
#  2   type                  9868 non-null   object
#  3   description           9749 non-null   object
#  4   release_year          9868 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9868 non-null   int64
#  7   genres                9868 non-null   object
#  8   production_countries  9868 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9201 non-null   object
#  11  imdb_score            8847 non-null   float64
#  12  imdb_votes            8837 non-null   float64
#  13  tmdb_popularity       9321 non-null   float64
#  14  tmdb_score            7788 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
df.head()
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
#                                               genres production_countries  \
# ...

# %%
df.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   9868.000000  9868.000000  1357.000000  8847.000000  8.837000e+03
# mean    2001.345561    85.979124     2.791452     5.976534  8.536485e+03
# std       25.792295    33.515714     4.148958     1.344028  4.592768e+04
# min     1912.000000     1.000000     1.000000     1.100000  5.000000e+00
# 25%     1996.000000    65.000000     1.000000     5.100000  1.180000e+02
# 50%     2014.000000    89.000000     1.000000     6.100000  4.640000e+02
# 75%     2018.000000   102.000000     3.000000     6.900000  2.237000e+03
# max     2022.000000   549.000000    51.000000     9.900000  1.133692e+06
#
#        tmdb_popularity   tmdb_score
# count      9321.000000  7788.000000
# mean          6.912168     5.984117
# std          30.008727     1.518040
# min           0.000011     0.800000
# 25%           1.234000     5.100000
# 50%           2.537000     6.000000
# 75%           5.640000     6.900000
# ...

# %%
missing[missing>0]
# Out:
# description           119
# age_certification    6484
# seasons              8511
# imdb_id               667
# imdb_score           1021
# imdb_votes           1031
# tmdb_popularity       547
# tmdb_score           2080
# dtype: int64

# %%
df.dropna(subset = ['description'],axis = 0,inplace=True)

# %%
6378/9868
# Out:
# 0.646331576813944

# %%
df.groupby('type')['age_certification'].apply(lambda x: x.isna().mean() * 100)
# Out:
# type
# MOVIE    68.063635
# SHOW     48.642534
# Name: age_certification, dtype: float64

# %% [markdown]
# age_certification was excluded because it contained a high proportion of missing values, with approximately 68% missing for movies and 49% for shows.

# %%
df.dropna(subset = ['age_certification'],axis = 0,inplace=True)

# %%
df.groupby('type')['seasons'].apply(lambda x: x.isna().mean()*100)
# Out:
# type
# MOVIE    100.0
# SHOW       0.0
# Name: seasons, dtype: float64

# %%
#no. of episode in each seasons
df[df['type'] == 'SHOW']['seasons'].value_counts().sort_index()
# Out:
# seasons
# 1.0     261
# 2.0     137
# 3.0      88
# 4.0      48
# 5.0      30
# 6.0      39
# 7.0      18
# 8.0      12
# 9.0       6
# 10.0      8
# 11.0      5
# 12.0      4
# 13.0      2
# 14.0      3
# 15.0      1
# 16.0      2
# 17.0      1
# 18.0      1
# 22.0      3
# 24.0      3
# 25.0      1
# 26.0      1
# 28.0      1
# 31.0      1
# 33.0      1
# 34.0      1
# 35.0      1
# 42.0      1
# 49.0      1
# Name: count, dtype: int64

# %%
df.loc[df['type'] == 'MOVIE', 'seasons'] = 'Not Applicable'

# %%
df.groupby('type')['seasons'].apply(lambda x: x.isna().mean()*100)
# Out:
# type
# MOVIE    0.0
# SHOW     0.0
# Name: seasons, dtype: float64

# %%
df['seasons'].value_counts()
# Out:
# seasons
# Not Applicable    2690
# 1.0                261
# 2.0                137
# 3.0                 88
# 4.0                 48
# 6.0                 39
# 5.0                 30
# 7.0                 18
# 8.0                 12
# 10.0                 8
# 9.0                  6
# 11.0                 5
# 12.0                 4
# 22.0                 3
# 14.0                 3
# 24.0                 3
# 13.0                 2
# 16.0                 2
# 49.0                 1
# 31.0                 1
# 26.0                 1
# 35.0                 1
# 42.0                 1
# 34.0                 1
# 33.0                 1
# 25.0                 1
# 17.0                 1
# 28.0                 1
# 18.0                 1
# 15.0                 1
# Name: count, dtype: int64

# %%
missing[missing>0]
# Out:
# description           119
# age_certification    6484
# seasons              8511
# imdb_id               667
# imdb_score           1021
# imdb_votes           1031
# tmdb_popularity       547
# tmdb_score           2080
# dtype: int64

# %%
df['imdb_score'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df_genres_exploded.head()
# Out:
#         id              title  type  \
# 0  ts20945  The Three Stooges  SHOW
# 0  ts20945  The Three Stooges  SHOW
# 0  ts20945  The Three Stooges  SHOW
# 0  ts20945  The Three Stooges  SHOW
# 0  ts20945  The Three Stooges  SHOW
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 0  The Three Stooges were an American vaudeville ...          1934
# 0  The Three Stooges were an American vaudeville ...          1934
# 0  The Three Stooges were an American vaudeville ...          1934
# 0  The Three Stooges were an American vaudeville ...          1934
#
#   age_certification  runtime     genres production_countries seasons  \
# 0             TV-PG       19     comedy               ['US']    26.0
# 0             TV-PG       19     family               ['US']    26.0
# 0             TV-PG       19  animation               ['US']    26.0
# ...

# %%
df['imdb_score'].fillna(df['imdb_score'].mean(),inplace=True)
df['imdb_votes'].fillna(df['imdb_votes'].mean(),inplace=True)
df['tmdb_popularity'].fillna(df['tmdb_popularity'].mean(),inplace=True)
df['tmdb_score'].fillna(df['tmdb_score'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# id                      0
# title                   0
# type                    0
# description             0
# release_year            0
# age_certification       0
# runtime                 0
# genres                  0
# production_countries    0
# seasons                 0
# imdb_id                 0
# imdb_score              0
# imdb_votes              0
# tmdb_popularity         0
# tmdb_score              0
# dtype: int64

# %%
df.dropna(subset = ['imdb_id'],axis = 0,inplace=True)

# %%
df['production_countries'].value_counts()
# Out:
# production_countries
# ['US']                                              1759
# ['GB']                                               236
# ['IN']                                               206
# ['CA']                                               124
# ['JP']                                                76
#                                                     ...
# ['HU', 'US']                                           1
# ['US', 'CA', 'JP']                                     1
# ['FR', 'DE', 'GR', 'JP', 'MX', 'CH', 'BE', 'CA']       1
# ['BE', 'EE', 'RS', 'SE', 'GB']                         1
# ['ZA', 'LY']                                           1
# Name: count, Length: 298, dtype: int64

# %%
df['genres'].value_counts()
# Out:
# genres
# ['drama']                                                            176
# ['comedy']                                                           120
# ['documentation']                                                     89
# ['drama', 'comedy']                                                   62
# ['drama', 'romance']                                                  53
#                                                                     ...
# ['action', 'romance', 'family']                                        1
# ['action', 'animation', 'family', 'comedy', 'fantasy', 'romance']      1
# ['drama', 'romance', 'war']                                            1
# ['drama', 'family', 'fantasy', 'romance', 'comedy']                    1
# ['comedy', 'family', 'animation', 'action', 'fantasy', 'horror']       1
# Name: count, Length: 1183, dtype: int64

# %%
df_genres_exploded['genres'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='genres'>

# %%
df_genres_exploded = df.explode('genres').reset_index(drop=True)

# %%
df_genres_exploded.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
sns.barplot(x = 'genres',y = 'imdb_score',data = df_genres_exploded)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # almost all genres contain better score

# %%
sns.barplot(x = 'genres',y = 'runtime',data = df_genres_exploded)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #least runtime animation,reality and other genre 's runtime is better

# %%
sns.barplot(x = 'genres',y = 'tmdb_popularity',data = df_genres_exploded)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #least popularity genre wise western,music,documentation
# #most popular genre scifi,fantasy,animation

# %%
df.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
df_genres_exploded
# Out:
#              id                          title   type  \
# 0       ts20945              The Three Stooges   SHOW
# 1       tm87233          It's a Wonderful Life  MOVIE
# 2      tm112415             Tell Your Children  MOVIE
# 3      tm159975            The Little Princess  MOVIE
# 4          tm52             A Farewell to Arms  MOVIE
# ...         ...                            ...    ...
# 3872   tm235542       The Colonel's Stray Dogs  MOVIE
# 3873   tm235542       The Colonel's Stray Dogs  MOVIE
# 3874  tm1032946  Ester Steinberg: Burning Bush  MOVIE
# 3875   tm901122                        The Bid  MOVIE
# 3876   tm534294                       Hal King  MOVIE
#
#                                             description  release_year  \
# 0     The Three Stooges were an American vaudeville ...          1934
# 1     A holiday favourite for generations...  George...          1946
# 2     High-school principal Dr. Alfred Carroll relat...          1938
# ...

# %%
df_genres_exploded.dropna(subset=['production_countries'],axis =0,inplace=True)

# %%
df_genres_exploded.isnull().sum()
# Out:
# id                      0
# title                   0
# type                    0
# description             0
# release_year            0
# age_certification       0
# runtime                 0
# genres                  0
# production_countries    0
# seasons                 0
# imdb_id                 0
# imdb_score              0
# imdb_votes              0
# tmdb_popularity         0
# tmdb_score              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
sns.scatterplot(x = 'imdb_score',y = 'imdb_votes',data = df_genres_exploded)
plt.show()
